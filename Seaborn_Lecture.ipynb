# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Styles and Color

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.countplot(x='sex', data=tips)

# %%
sns.set_style('darkgrid') # darkgrid, whitegrid, dark, white, ticks
sns.countplot(x='sex', data=tips)

# %%
sns.set_style('ticks') # darkgrid, whitegrid, dark, white, ticks
sns.countplot(x='sex', data=tips)

# %% [markdown]
# ## Spine Removal

# %%
sns.countplot(x='sex', data=tips)
sns.despine()

# %%
sns.countplot(x='sex', data=tips)
sns.despine(left=True)

# %% [markdown]
# ## Size and Aspect

# %%
plt.figure(figsize=(12, 3))
sns.countplot(x='sex', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', size=2, aspect=4, data=tips)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Scale and Context

# %%
sns.set_context('poster', font_scale=4)# paper, talk, notebook, poster
sns.countplot(x='sex', data=tips, palette='coolwarm')

# %% [markdown]
# # Grids

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.set_context('notebook', font_scale=1)
sns.set_style('darkgrid')

# %% [markdown]
# ## PairGrid

# %%
sns.PairGrid(iris)

# %%
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(plt.stackplot)

# %% [markdown]
# ## Pairplots

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue='species', palette='rainbow')

# %% [markdown]
# ## FacetGrid

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(tips, col='time', row='smoker')

# %%
g = sns.FacetGrid(tips, col='time', row='smoker')
g = g.map(plt.hist, 'total_bill')

# %%
g = sns.FacetGrid(tips, col='time', row='smoker', hue='sex')
g = g.map(plt.scatter, 'total_bill', 'tip').add_legend()

# %% [markdown]
# ## JointGrid

# %%
g = sns.JointGrid(x='total_bill', y='tip', data=tips)

# %%
g = sns.JointGrid(x='total_bill', y='tip', data=tips)
g = g.plot(sns.regplot, sns.histplot)

# %% [markdown]
# # Distribution plots

# %% [markdown]
# ## HistPlot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(tips['total_bill'])

# %%
sns.histplot(tips['total_bill'], kde=True)

# %%
sns.histplot(tips['total_bill'], kde=True, bins=30)

# %% [markdown]
# ## Jointplots

# %%
sns.jointplot(x= 'total_bill', y= 'tip', data=tips, kind='scatter')

# %%
sns.jointplot(x= 'total_bill', y= 'tip', data=tips, kind='reg')

# %%
sns.jointplot(x= 'total_bill', y= 'tip', data=tips, kind='resid')

# %%
sns.jointplot(x= 'total_bill', y= 'tip', data=tips, kind='kde')

# %%
sns.jointplot(x= 'total_bill', y= 'tip', data=tips, kind='hex')

# %% [markdown]
# ## Pairplots

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue='sex', palette='plasma')

# %% [markdown]
# ## Rugplots

# %%
sns.rugplot(tips['total_bill'])

# %% [markdown]
# ## Kde plots

# %% [markdown]
# To read more about Kernel density estimation go [here](https://en.wikipedia.org/wiki/Kernel_density_estimation#Bandwidth_selection)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# create datasets
dataset = np.random.randn(25)

# create rugplot
sns.rugplot(dataset)

# set-up x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min, x_max, 100)

# setup the bandwith
bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2

# create empty kernel list
kernel_list = []

# plot each basis function
for data_point in dataset:
    
    # create a kernel for each point and append to the list
    kernel = stats.norm(data_point, bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    # Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis, kernel, color='grey', alpha=0.5)
    
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
# To get the kde plot we can sum these basis functions

# Plot sum of basis function
sum_of_kde = np.sum(kernel_list, axis=0)

# Plot figure
fig = plt.plot(x_axis, sum_of_kde, color='red')

# Add rugplot
sns.rugplot(dataset, color='red')

# %%
sns.kdeplot(tips['total_bill'])
sns.rugplot(tips['total_bill'])

# %% [markdown]
# # Categorical data plots

# %% [markdown]
# ## Barplots and Countplots

# %% [markdown]
# ### Barplots

# %%
sns.barplot(x='sex', y='total_bill', data=tips)

# %%
sns.barplot(x='sex', y='total_bill', data=tips, estimator=np.std)

# %% [markdown]
# ### countplots

# %%
sns.countplot(x='sex', data=tips)

# %% [markdown]
# ## Boxplots and Violinplots

# %%
sns.boxplot(x='day', y='total_bill', data=tips, palette='inferno')

# %%
sns.boxplot(data=tips, palette='rainbow', orient='h')

# %%
sns.boxplot(x='day', y='total_bill', hue='smoker', data=tips, palette='inferno')

# %%
sns.violinplot(x='day', y='total_bill', data=tips, palette='inferno')

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex', palette='inferno')

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex', split=True, palette='inferno')

# %% [markdown]
# ## Stripplot and Swarmplots

# %% [markdown]
# ### Stripplots

# %%
sns.stripplot(x="day", y="total_bill", data=tips)

# %%
sns.stripplot(x="day", y="total_bill", data=tips, hue='sex', palette='Set1')

# %%
sns.stripplot(x="day", y="total_bill", data=tips, hue='sex', palette='Set1', dodge=True)

# %% [markdown]
# ### Swarmplots

# %%
sns.swarmplot(x='day', y='total_bill', data=tips)

# %%
sns.swarmplot(x="day", y="total_bill", data=tips, hue='sex', palette='Set1', dodge=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## combining categorical plots

# %%
sns.violinplot(x='day', y='total_bill', data=tips, palette='cividis')
sns.swarmplot(x='day', y='total_bill', data=tips, color='black', size=3)

# %% [markdown]
# ## catplots

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='bar')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='strip')

# %% [markdown]
# # Regression Plots

# %% [markdown]
# ## lmplot()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', palette='Set2')

# %% [markdown]
# ### Working with Markers

# %%
# https://matplotlib.org/stable/api/markers_api.html
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', palette='Set1', markers=['o', 'v'], scatter_kws={'s': 100})

# %% [markdown]
# ## Using a Grid

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex')

# %%
sns.lmplot(x='total_bill', y='tip', row='sex', col='time', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='day', hue='sex', palette='Set1')

# %% [markdown]
# ## Aspect and Size

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='day', hue='sex', palette='Set3', aspect=0.6, size=8)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Matrix Plot

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# ## Heatmap

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Matrix form for correlation data
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())

# %%
sns.heatmap(tips.corr(), cmap='coolwarm', annot=True)

# %%
flights.pivot_table(values='passengers', index='month', columns='year')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
pvflights = flights.pivot_table(values='passengers', index='month', columns='year')
sns.heatmap(pvflights)

# %%
sns.heatmap(pvflights, cmap='magma', linecolor='white', linewidths=1)

# %% [markdown]
# ## Clustermap

# %%
sns.clustermap(pvflights)

# %%
sns.clustermap(pvflights, cmap='coolwarm', standard_scale=1)
